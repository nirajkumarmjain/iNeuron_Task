# %%
import pymongo
import pandas as pd
import os
import csv
import logging as lg
import ast

class loggerClass:
    def __init__(self):
        logger = lg.getLogger()
        fhandler = lg.FileHandler(filename='MongoDB_Operation.log', mode='a')
        formatter = lg.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        fhandler.setFormatter(formatter)
        if (logger.hasHandlers()):
            logger.handlers.clear()
        logger.addHandler(fhandler)
        logger.setLevel(lg.INFO)
     
    def logFunc(self,lg_type,content):
        if lg_type == "INFO":
            lg.info(str(content))
            lg.shutdown()
        elif lg_type == "ERROR":
            lg.error(str(content))
            lg.shutdown()
        else:
            lg.info(str(content))
            lg.shutdown()

# %%
class MongoDBOperation:
    def __init__(self,connection_url,dbname):
        self.__connection_url = connection_url
        self.__dbname= dbname
        self.__lg = loggerClass()
        
    def db_Connection(self):
        try:
            client = pymongo.MongoClient(self.__connection_url)
            return client[self.__dbname]
        except Exception as e:
            self.__lg.logFunc('error', "Error while establishing connection with Mongo DB:" + str(e))
            
    def checkExistence_COL(self,collection_name):
        try:
            db = self.db_Connection()
            collection_list = db.list_collection_names()
            if collection_name in collection_list:
                return True
            else:
                return False
        except Exception as e:
            self.__lg.logFunc('error', "Error while finding collection in Mongo DB:" + str(e))    
        
                
    def read_File(self,file_path,file_name,delim):
        """Reads file and returns DataFrame
            Parameters: File Path,File name, Delimiter
            Returns Dataframe"""
        try:
            file_location = file_path + '\\' + file_name
            self.__lg.logFunc("info", f"Opening File {file_location}")
            df = pd.read_csv(file_location, delimiter=delim)
            df.columns = df.columns.str.replace(' ','_')
            self.__lg.logFunc("info", f"File read complete")
            return df

        except Exception as e:
            self.__lg.logFunc('error', f"Error while reading file:{file_path} {file_name}" + str(e))
          
    def insert_Data(self,file_path,file_name,delim,collection_name):
        """Inserts multiple documents for given collection name
            Parameters: File Path,File name, Delimiter,Collection_name"""
        try:
            db = self.db_Connection()
            collec = db[collection_name]
            data = self.read_File(file_path,file_name,delim)
            collec.insert_many(data.to_dict('records'))
            print(f"Inserted {data.shape[0]} records")
            self.__lg.logFunc("info", f"Inserted {data.shape[0]} records")

        except Exception as e:
            self.__lg.logFunc('error', f"Error while inserting data from file:{file_path} {file_name}" + str(e))

    def find_one_Data(self,collection_name):
        """Finds data from given collection name
        Parameters: Collection name"""
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                data = collec.find_one()
                print(data)
                self.__lg.logFunc("info", f"The find_one method on {collection_name} has been performed successfully")
            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                
        except Exception as e:
            self.__lg.logFunc('error', f"Error while finding data from collection:{collection_name}" + str(e))  
            
    def find_all_Data(self,collection_name):
        """Finds data from given collection name
        Parameters: Collection name"""
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                data = collec.find()
                for idx,record in enumerate(data):
                    print(f"{idx} : {record}")
                self.__lg.logFunc("info", f"The find method on {collection_name} has been performed successfully")
            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                
        except Exception as e:
            self.__lg.logFunc('error', f"Error while finding data from collection:{collection_name}" + str(e))  
                              
    def filter_all_Data(self,collection_name,**kwargs):
        """Finds data from given collection name
        Parameters: Collection name, Selection Criteria in Key-value pair(Eg: Column name:[[operator, [List of filter values]])"""
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                filter_criteria = '{' + ", ".join({'"'+key+'"'" :{'"+kwargs[key][0]+"':"+str(kwargs[key][1])+"}" for key in kwargs.keys()}) +'}'
                filter_criteria = ast.literal_eval(filter_criteria)
                data = collec.find(filter_criteria)
                count = collec.count_documents(filter_criteria)
                print(f"Found {count} records")
                for doc in data:
                    print(doc)
                self.__lg.logFunc("info", f"The filter criteria {filter_criteria} of {collection_name} has been performed successfully")
                self.__lg.logFunc("info", str(count) + ' records fetched')
                
            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                
        except Exception as e:
            self.__lg.logFunc('error', f"Error while finding data from collection:{collection_name}" + str(e))      
            
    def update_Data(self,collection_name,filter_criteria,update_criteria):
        """Updates data for given collection name
        Parameters: Collection name, Filter Criteria in dictionary format(Eg: Column name:[[operator, [List of filter values]]),
        Update Criteria in Dictionary format """
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                filter_criteria_ = '{' + ", ".join({'"'+key+'"'" :{'"+filter_criteria[key][0]+"':"+str(filter_criteria[key][1])+"}" for key in filter_criteria.keys()}) +'}'
                filter_criteria_ = ast.literal_eval(filter_criteria_)
                data = collec.find(filter_criteria_)
                count = collec.count_documents(filter_criteria_)
                update_criteria_ = {"$set" : update_criteria}
                collec.update_many(filter_criteria_,update_criteria_)
                print(f"Updated {count} records")
                self.__lg.logFunc("info", f"The Update criteria {update_criteria_} over {collection_name} has been performed successfully")
                self.__lg.logFunc("info", str(count) + ' records updated')

            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                
        except Exception as e:
            self.__lg.logFunc('error', f"Error while updating data in collection:{collection_name} with criteria {update_criteria_}" + str(e)) 
        
    def delete_many_Data(self,collection_name,**kwargs):
        """Deletes data from given collection name
        Parameters: Collection name, Selection Criteria in Key-value pair(Eg: Column name:[[operator, [List of filter values]])"""
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                filter_criteria = '{' + ", ".join({'"'+key+'"'" :{'"+kwargs[key][0]+"':"+str(kwargs[key][1])+"}" for key in kwargs.keys()}) +'}'
                filter_criteria = ast.literal_eval(filter_criteria)
                count = collec.count_documents(filter_criteria)
                data = collec.delete_many(filter_criteria)
                print(f"Deleted {count} records")
                self.__lg.logFunc("info", f"The Delete criteria {filter_criteria} of {collection_name} has been performed successfully")
                self.__lg.logFunc("info", str(count) + ' records deleted')
                
            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                
        except Exception as e:
            self.__lg.logFunc('error', f"Error while deleting data from collection:{collection_name}" + str(e))                

    def drop_collection(self,collection_name):
        """Drops given collection name
        Parameters: Collection name"""
        try:
            if(self.checkExistence_COL(collection_name)):
                db = self.db_Connection()
                collec = db[collection_name]
                collec.drop()
                print(f"{collection_name} dropped")
                self.__lg.logFunc("info", f"The collection {collection_name} has been dropped")
                
            else:
                self.__lg.logFunc('error', f"Error while finding collection :{collection_name}")
                            
        except Exception as e:
            self.__lg.logFunc('error', f"Error while dropping collection:{collection_name}" + str(e))

# %%
mdb = MongoDBOperation("mongodb+srv://mongodb:mongodb@cluster0.lrz7y.mongodb.net/myFirstDatabase?retryWrites=true&w=majority",'carbon_db')

# %%
mdb.insert_Data("D:\python_1","carbon_nanotubes.csv",";","carbon_collection")
# Out:
# Inserted 10721 records

# %%
mdb.checkExistence_COL('carbon_collection')
# Out:
# True

# %%
mdb.find_one_Data('carbon_collection')
# Out:
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd720'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,679005', 'Initial_atomic_coordinate_v': '0,701318', 'Initial_atomic_coordinate_w': '0,017033', "Calculated_atomic_coordinates_u'": '0,721039', "Calculated_atomic_coordinates_v'": '0,730232', "Calculated_atomic_coordinates_w'": '0,017014'}

# %%
mdb.find_all_Data('carbon_collection')
# Out:
# 0 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd720'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,679005', 'Initial_atomic_coordinate_v': '0,701318', 'Initial_atomic_coordinate_w': '0,017033', "Calculated_atomic_coordinates_u'": '0,721039', "Calculated_atomic_coordinates_v'": '0,730232', "Calculated_atomic_coordinates_w'": '0,017014'}
# 1 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd721'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,717298', 'Initial_atomic_coordinate_v': '0,642129', 'Initial_atomic_coordinate_w': '0,231319', "Calculated_atomic_coordinates_u'": '0,738414', "Calculated_atomic_coordinates_v'": '0,65675', "Calculated_atomic_coordinates_w'": '0,232369'}
# 2 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd722'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,489336', 'Initial_atomic_coordinate_v': '0,303751', 'Initial_atomic_coordinate_w': '0,088462', "Calculated_atomic_coordinates_u'": '0,477676', "Calculated_atomic_coordinates_v'": '0,263221', "Calculated_atomic_coordinates_w'": '0,088712'}
# 3 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd723'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,413957', 'Initial_atomic_coordinate_v': '0,632996', 'Initial_atomic_coordinate_w': '0,040843', "Calculated_atomic_coordinates_u'": '0,408823', "Calculated_atomic_coordinates_v'": '0,657897', "Calculated_atomic_coordinates_w'": '0,039796'}
# 4 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd724'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,334292', 'Initial_atomic_coordinate_v': '0,543401', 'Initial_atomic_coordinate_w': '0,15989', "Calculated_atomic_coordinates_u'": '0,303349', "Calculated_atomic_coordinates_v'": '0,558807', "Calculated_atomic_coordinates_w'": '0,157373'}
# 5 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd725'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,510664', 'Initial_atomic_coordinate_v': '0,696249', 'Initial_atomic_coordinate_w': '0,255128', "Calculated_atomic_coordinates_u'": '0,496977', "Calculated_atomic_coordinates_v'": '0,725608', "Calculated_atomic_coordinates_w'": '0,25597'}
# 6 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd726'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,413957', 'Initial_atomic_coordinate_v': '0,632996', 'Initial_atomic_coordinate_w': '0,374176', "Calculated_atomic_coordinates_u'": '0,390878', "Calculated_atomic_coordinates_v'": '0,657645', "Calculated_atomic_coordinates_w'": '0,374735'}
# 7 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd727'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,712552', 'Initial_atomic_coordinate_v': '0,55479', 'Initial_atomic_coordinate_w': '0,112271', "Calculated_atomic_coordinates_u'": '0,750056', "Calculated_atomic_coordinates_v'": '0,561494', "Calculated_atomic_coordinates_w'": '0,114944'}
# 8 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd728'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,320995', 'Initial_atomic_coordinate_v': '0,298682', 'Initial_atomic_coordinate_w': '0,1837', "Calculated_atomic_coordinates_u'": '0,281301', "Calculated_atomic_coordinates_v'": '0,261433', "Calculated_atomic_coordinates_w'": '0,182779'}
# 9 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd729'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,394742', 'Initial_atomic_coordinate_v': '0,279367', 'Initial_atomic_coordinate_w': '0,302747', "Calculated_atomic_coordinates_u'": '0,35086', "Calculated_atomic_coordinates_v'": '0,2335', "Calculated_atomic_coordinates_w'": '0,302196'}
# 10 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72a'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,282702', 'Initial_atomic_coordinate_v': '0,357871', 'Initial_atomic_coordinate_w': '0,397985', "Calculated_atomic_coordinates_u'": '0,229138', "Calculated_atomic_coordinates_v'": '0,328729', "Calculated_atomic_coordinates_w'": '0,398581'}
# 11 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72b'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,320995', 'Initial_atomic_coordinate_v': '0,298682', 'Initial_atomic_coordinate_w': '0,517033', "Calculated_atomic_coordinates_u'": '0,278752', "Calculated_atomic_coordinates_v'": '0,269615', "Calculated_atomic_coordinates_w'": '0,51733'}
# 12 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72c'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,605258', 'Initial_atomic_coordinate_v': '0,720633', 'Initial_atomic_coordinate_w': '0,469414', "Calculated_atomic_coordinates_u'": '0,613415', "Calculated_atomic_coordinates_v'": '0,760009', "Calculated_atomic_coordinates_w'": '0,469452'}
# 13 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72d'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,510664', 'Initial_atomic_coordinate_v': '0,696249', 'Initial_atomic_coordinate_w': '0,588462', "Calculated_atomic_coordinates_u'": '0,521991', "Calculated_atomic_coordinates_v'": '0,736991', "Calculated_atomic_coordinates_w'": '0,588946'}
# 14 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72e'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,679005', 'Initial_atomic_coordinate_v': '0,701318', 'Initial_atomic_coordinate_w': '0,6837', "Calculated_atomic_coordinates_u'": '0,718811', "Calculated_atomic_coordinates_v'": '0,738577', "Calculated_atomic_coordinates_w'": '0,68244'}
# 15 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd72f'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,605258', 'Initial_atomic_coordinate_v': '0,720633', 'Initial_atomic_coordinate_w': '0,802747', "Calculated_atomic_coordinates_u'": '0,649178', "Calculated_atomic_coordinates_v'": '0,766301', "Calculated_atomic_coordinates_w'": '0,80193'}
# 16 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd730'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,665708', 'Initial_atomic_coordinate_v': '0,456599', 'Initial_atomic_coordinate_w': '0,326557', "Calculated_atomic_coordinates_u'": '0,680389', "Calculated_atomic_coordinates_v'": '0,444562', "Calculated_atomic_coordinates_w'": '0,327502'}
# 17 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd731'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,712552', 'Initial_atomic_coordinate_v': '0,55479', 'Initial_atomic_coordinate_w': '0,445605', "Calculated_atomic_coordinates_u'": '0,737216', "Calculated_atomic_coordinates_v'": '0,552056', "Calculated_atomic_coordinates_w'": '0,443517'}
# 18 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd732'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,586043', 'Initial_atomic_coordinate_v': '0,367004', 'Initial_atomic_coordinate_w': '0,540843', "Calculated_atomic_coordinates_u'": '0,591153', "Calculated_atomic_coordinates_v'": '0,342069', "Calculated_atomic_coordinates_w'": '0,540172'}
# 19 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd733'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,665708', 'Initial_atomic_coordinate_v': '0,456599', 'Initial_atomic_coordinate_w': '0,65989', "Calculated_atomic_coordinates_u'": '0,697242', "Calculated_atomic_coordinates_v'": '0,441516', "Calculated_atomic_coordinates_w'": '0,657521'}
# 20 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd734'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,287448', 'Initial_atomic_coordinate_v': '0,44521', 'Initial_atomic_coordinate_w': '0,612271', "Calculated_atomic_coordinates_u'": '0,249571', "Calculated_atomic_coordinates_v'": '0,438057', "Calculated_atomic_coordinates_w'": '0,614939'}
# 21 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd735'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,282702', 'Initial_atomic_coordinate_v': '0,357871', 'Initial_atomic_coordinate_w': '0,731319', "Calculated_atomic_coordinates_u'": '0,262916', "Calculated_atomic_coordinates_v'": '0,343512', "Calculated_atomic_coordinates_w'": '0,732213'}
# 22 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd736'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,334292', 'Initial_atomic_coordinate_v': '0,543401', 'Initial_atomic_coordinate_w': '0,826557', "Calculated_atomic_coordinates_u'": '0,320053', "Calculated_atomic_coordinates_v'": '0,555754', "Calculated_atomic_coordinates_w'": '0,827503'}
# 23 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd737'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,287448', 'Initial_atomic_coordinate_v': '0,44521', 'Initial_atomic_coordinate_w': '0,945605', "Calculated_atomic_coordinates_u'": '0,262054', "Calculated_atomic_coordinates_v'": '0,44817', "Calculated_atomic_coordinates_w'": '0,943402'}
# 24 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd738'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,717298', 'Initial_atomic_coordinate_v': '0,642129', 'Initial_atomic_coordinate_w': '0,897985', "Calculated_atomic_coordinates_u'": '0,770521', "Calculated_atomic_coordinates_v'": '0,670869', "Calculated_atomic_coordinates_w'": '0,898389'}
# 25 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd739'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,489336', 'Initial_atomic_coordinate_v': '0,303751', 'Initial_atomic_coordinate_w': '0,755128', "Calculated_atomic_coordinates_u'": '0,50356', "Calculated_atomic_coordinates_v'": '0,27443', "Calculated_atomic_coordinates_w'": '0,75629'}
# 26 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73a'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,586043', 'Initial_atomic_coordinate_v': '0,367004', 'Initial_atomic_coordinate_w': '0,874176', "Calculated_atomic_coordinates_u'": '0,609', "Calculated_atomic_coordinates_v'": '0,342123', "Calculated_atomic_coordinates_w'": '0,875088'}
# 27 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73b'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,394742', 'Initial_atomic_coordinate_v': '0,279367', 'Initial_atomic_coordinate_w': '0,969414', "Calculated_atomic_coordinates_u'": '0,385666', "Calculated_atomic_coordinates_v'": '0,240071', "Calculated_atomic_coordinates_w'": '0,969157'}
# 28 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,591598', 'Initial_atomic_coordinate_v': '0,760361', 'Initial_atomic_coordinate_w': '0,05909', "Calculated_atomic_coordinates_u'": '0,59912', "Calculated_atomic_coordinates_v'": '0,779052', "Calculated_atomic_coordinates_w'": '0,058651'}
# 29 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,24301', 'Initial_atomic_coordinate_v': '0,424391', 'Initial_atomic_coordinate_w': '0,020628', "Calculated_atomic_coordinates_u'": '0,222068', "Calculated_atomic_coordinates_v'": '0,414703', "Calculated_atomic_coordinates_w'": '0,020882'}
# 30 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,348135', 'Initial_atomic_coordinate_v': '0,611237', 'Initial_atomic_coordinate_w': '0,084731', "Calculated_atomic_coordinates_u'": '0,337437', "Calculated_atomic_coordinates_v'": '0,618899', "Calculated_atomic_coordinates_w'": '0,085676'}
# 31 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd73f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,300826', 'Initial_atomic_coordinate_v': '0,550669', 'Initial_atomic_coordinate_w': '0,174474', "Calculated_atomic_coordinates_u'": '0,287789', "Calculated_atomic_coordinates_v'": '0,556575', "Calculated_atomic_coordinates_w'": '0,174486'}
# 32 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd740'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,732854', 'Initial_atomic_coordinate_v': '0,724426', 'Initial_atomic_coordinate_w': '0,123192', "Calculated_atomic_coordinates_u'": '0,754953', "Calculated_atomic_coordinates_v'": '0,742501', "Calculated_atomic_coordinates_w'": '0,123074'}
# 33 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd741'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,696244', 'Initial_atomic_coordinate_v': '0,751243', 'Initial_atomic_coordinate_w': '0,212936', "Calculated_atomic_coordinates_u'": '0,716721', "Calculated_atomic_coordinates_v'": '0,774579', "Calculated_atomic_coordinates_w'": '0,211887'}
# 34 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd742'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,764136', 'Initial_atomic_coordinate_v': '0,633981', 'Initial_atomic_coordinate_w': '0,277038', "Calculated_atomic_coordinates_u'": '0,787393', "Calculated_atomic_coordinates_v'": '0,647285', "Calculated_atomic_coordinates_w'": '0,277407'}
# 35 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd743'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,755932', 'Initial_atomic_coordinate_v': '0,684567', 'Initial_atomic_coordinate_w': '0,366782', "Calculated_atomic_coordinates_u'": '0,775712', "Calculated_atomic_coordinates_v'": '0,700545', "Calculated_atomic_coordinates_w'": '0,366505'}
# 36 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd744'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,699174', 'Initial_atomic_coordinate_v': '0,449331', 'Initial_atomic_coordinate_w': '0,007807', "Calculated_atomic_coordinates_u'": '0,72086', "Calculated_atomic_coordinates_v'": '0,444281', "Calculated_atomic_coordinates_w'": '0,00759'}
# 37 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd745'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,734908', 'Initial_atomic_coordinate_v': '0,512843', 'Initial_atomic_coordinate_w': '0,097551', "Calculated_atomic_coordinates_u'": '0,762097', "Calculated_atomic_coordinates_v'": '0,516121', "Calculated_atomic_coordinates_w'": '0,096337'}
# 38 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd746'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,303756', 'Initial_atomic_coordinate_v': '0,248757', 'Initial_atomic_coordinate_w': '0,046269', "Calculated_atomic_coordinates_u'": '0,293584', "Calculated_atomic_coordinates_v'": '0,229065', "Calculated_atomic_coordinates_w'": '0,047346'}
# 39 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd747'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,351772', 'Initial_atomic_coordinate_v': '0,236542', 'Initial_atomic_coordinate_w': '0,136013', "Calculated_atomic_coordinates_u'": '0,349972', "Calculated_atomic_coordinates_v'": '0,22059', "Calculated_atomic_coordinates_w'": '0,136027'}
# 40 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd748'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,244068', 'Initial_atomic_coordinate_v': '0,315433', 'Initial_atomic_coordinate_w': '0,200115', "Calculated_atomic_coordinates_u'": '0,232016', "Calculated_atomic_coordinates_v'": '0,304156', "Calculated_atomic_coordinates_w'": '0,201163'}
# 41 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd749'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,267146', 'Initial_atomic_coordinate_v': '0,275574', 'Initial_atomic_coordinate_w': '0,289859', "Calculated_atomic_coordinates_u'": '0,259193', "Calculated_atomic_coordinates_v'": '0,263096', "Calculated_atomic_coordinates_w'": '0,289735'}
# 42 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,465969', 'Initial_atomic_coordinate_v': '0,709835', 'Initial_atomic_coordinate_w': '0,238577', "Calculated_atomic_coordinates_u'": '0,467543', "Calculated_atomic_coordinates_v'": '0,732466', "Calculated_atomic_coordinates_w'": '0,238691'}
# 43 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,40427', 'Initial_atomic_coordinate_v': '0,665341', 'Initial_atomic_coordinate_w': '0,32832', "Calculated_atomic_coordinates_u'": '0,398427', "Calculated_atomic_coordinates_v'": '0,685067', "Calculated_atomic_coordinates_w'": '0,327159'}
# 44 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,591598', 'Initial_atomic_coordinate_v': '0,760361', 'Initial_atomic_coordinate_w': '0,392423', "Calculated_atomic_coordinates_u'": '0,599318', "Calculated_atomic_coordinates_v'": '0,782562', "Calculated_atomic_coordinates_w'": '0,392936'}
# 45 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,529645', 'Initial_atomic_coordinate_v': '0,742134', 'Initial_atomic_coordinate_w': '0,482166', "Calculated_atomic_coordinates_u'": '0,529179', "Calculated_atomic_coordinates_v'": '0,763965', "Calculated_atomic_coordinates_w'": '0,48165'}
# 46 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,59573', 'Initial_atomic_coordinate_v': '0,334659', 'Initial_atomic_coordinate_w': '0,161654', "Calculated_atomic_coordinates_u'": '0,613188', "Calculated_atomic_coordinates_v'": '0,322504', "Calculated_atomic_coordinates_w'": '0,16211'}
# 47 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd74f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,651865', 'Initial_atomic_coordinate_v': '0,388763', 'Initial_atomic_coordinate_w': '0,251397', "Calculated_atomic_coordinates_u'": '0,674862', "Calculated_atomic_coordinates_v'": '0,383646', "Calculated_atomic_coordinates_w'": '0,250882'}
# 48 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd750'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,470355', 'Initial_atomic_coordinate_v': '0,257866', 'Initial_atomic_coordinate_w': '0,3155', "Calculated_atomic_coordinates_u'": '0,476696', "Calculated_atomic_coordinates_v'": '0,239962', "Calculated_atomic_coordinates_w'": '0,316373'}
# 49 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd751'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,534031', 'Initial_atomic_coordinate_v': '0,290165', 'Initial_atomic_coordinate_w': '0,405243', "Calculated_atomic_coordinates_u'": '0,543931', "Calculated_atomic_coordinates_v'": '0,27459', "Calculated_atomic_coordinates_w'": '0,405442'}
# 50 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd752'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,24301', 'Initial_atomic_coordinate_v': '0,424391', 'Initial_atomic_coordinate_w': '0,353961', "Calculated_atomic_coordinates_u'": '0,22811', "Calculated_atomic_coordinates_v'": '0,42237', "Calculated_atomic_coordinates_w'": '0,353687'}
# 51 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd753'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,235864', 'Initial_atomic_coordinate_v': '0,366019', 'Initial_atomic_coordinate_w': '0,443705', "Calculated_atomic_coordinates_u'": '0,21931', "Calculated_atomic_coordinates_v'": '0,358527', "Calculated_atomic_coordinates_w'": '0,442351'}
# 52 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd754'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,300826', 'Initial_atomic_coordinate_v': '0,550669', 'Initial_atomic_coordinate_w': '0,507807', "Calculated_atomic_coordinates_u'": '0,27914', "Calculated_atomic_coordinates_v'": '0,555719', "Calculated_atomic_coordinates_w'": '0,50759'}
# 53 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd755'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,265092', 'Initial_atomic_coordinate_v': '0,487157', 'Initial_atomic_coordinate_w': '0,597551', "Calculated_atomic_coordinates_u'": '0,237903', "Calculated_atomic_coordinates_v'": '0,483879', "Calculated_atomic_coordinates_w'": '0,596337'}
# 54 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd756'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,696244', 'Initial_atomic_coordinate_v': '0,751243', 'Initial_atomic_coordinate_w': '0,546269', "Calculated_atomic_coordinates_u'": '0,706416', "Calculated_atomic_coordinates_v'": '0,770935', "Calculated_atomic_coordinates_w'": '0,547346'}
# 55 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd757'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,648228', 'Initial_atomic_coordinate_v': '0,763458', 'Initial_atomic_coordinate_w': '0,636013', "Calculated_atomic_coordinates_u'": '0,650028', "Calculated_atomic_coordinates_v'": '0,77941', "Calculated_atomic_coordinates_w'": '0,636027'}
# 56 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd758'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,755932', 'Initial_atomic_coordinate_v': '0,684567', 'Initial_atomic_coordinate_w': '0,700115', "Calculated_atomic_coordinates_u'": '0,767984', "Calculated_atomic_coordinates_v'": '0,695844', "Calculated_atomic_coordinates_w'": '0,701163'}
# 57 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd759'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,732854', 'Initial_atomic_coordinate_v': '0,724426', 'Initial_atomic_coordinate_w': '0,789859', "Calculated_atomic_coordinates_u'": '0,740808', "Calculated_atomic_coordinates_v'": '0,736904', "Calculated_atomic_coordinates_w'": '0,789735'}
# 58 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,734908', 'Initial_atomic_coordinate_v': '0,512843', 'Initial_atomic_coordinate_w': '0,430884', "Calculated_atomic_coordinates_u'": '0,76046', "Calculated_atomic_coordinates_v'": '0,51884', "Calculated_atomic_coordinates_w'": '0,432119'}
# 59 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,75699', 'Initial_atomic_coordinate_v': '0,575609', 'Initial_atomic_coordinate_w': '0,520628', "Calculated_atomic_coordinates_u'": '0,777932', "Calculated_atomic_coordinates_v'": '0,585297', "Calculated_atomic_coordinates_w'": '0,520882'}
# 60 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,351772', 'Initial_atomic_coordinate_v': '0,236542', 'Initial_atomic_coordinate_w': '0,469346', "Calculated_atomic_coordinates_u'": '0,345355', "Calculated_atomic_coordinates_v'": '0,221578', "Calculated_atomic_coordinates_w'": '0,469496'}
# 61 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,408402', 'Initial_atomic_coordinate_v': '0,239639', 'Initial_atomic_coordinate_w': '0,55909', "Calculated_atomic_coordinates_u'": '0,40088', "Calculated_atomic_coordinates_v'": '0,220949', "Calculated_atomic_coordinates_w'": '0,558651'}
# 62 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,267146', 'Initial_atomic_coordinate_v': '0,275574', 'Initial_atomic_coordinate_w': '0,623192', "Calculated_atomic_coordinates_u'": '0,245047', "Calculated_atomic_coordinates_v'": '0,257499', "Calculated_atomic_coordinates_w'": '0,623074'}
# 63 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd75f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,303756', 'Initial_atomic_coordinate_v': '0,248757', 'Initial_atomic_coordinate_w': '0,712936', "Calculated_atomic_coordinates_u'": '0,283279', "Calculated_atomic_coordinates_v'": '0,225421', "Calculated_atomic_coordinates_w'": '0,711887'}
# 64 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd760'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,40427', 'Initial_atomic_coordinate_v': '0,665341', 'Initial_atomic_coordinate_w': '0,661654', "Calculated_atomic_coordinates_u'": '0,386812', "Calculated_atomic_coordinates_v'": '0,677496', "Calculated_atomic_coordinates_w'": '0,66211'}
# 65 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd761'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,348135', 'Initial_atomic_coordinate_v': '0,611237', 'Initial_atomic_coordinate_w': '0,751397', "Calculated_atomic_coordinates_u'": '0,325138', "Calculated_atomic_coordinates_v'": '0,616354', "Calculated_atomic_coordinates_w'": '0,750882'}
# 66 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd762'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,529645', 'Initial_atomic_coordinate_v': '0,742134', 'Initial_atomic_coordinate_w': '0,8155', "Calculated_atomic_coordinates_u'": '0,523304', "Calculated_atomic_coordinates_v'": '0,760038', "Calculated_atomic_coordinates_w'": '0,816373'}
# 67 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd763'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,465969', 'Initial_atomic_coordinate_v': '0,709835', 'Initial_atomic_coordinate_w': '0,905243', "Calculated_atomic_coordinates_u'": '0,456069', "Calculated_atomic_coordinates_v'": '0,72541', "Calculated_atomic_coordinates_w'": '0,905442'}
# 68 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd764'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,764136', 'Initial_atomic_coordinate_v': '0,633981', 'Initial_atomic_coordinate_w': '0,943705', "Calculated_atomic_coordinates_u'": '0,78069', "Calculated_atomic_coordinates_v'": '0,641473', "Calculated_atomic_coordinates_w'": '0,942351'}
# 69 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd765'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,651865', 'Initial_atomic_coordinate_v': '0,388763', 'Initial_atomic_coordinate_w': '0,584731', "Calculated_atomic_coordinates_u'": '0,662563', "Calculated_atomic_coordinates_v'": '0,381101', "Calculated_atomic_coordinates_w'": '0,585676'}
# 70 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd766'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,699174', 'Initial_atomic_coordinate_v': '0,449331', 'Initial_atomic_coordinate_w': '0,674474', "Calculated_atomic_coordinates_u'": '0,712211', "Calculated_atomic_coordinates_v'": '0,443425', "Calculated_atomic_coordinates_w'": '0,674486'}
# 71 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd767'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,534031', 'Initial_atomic_coordinate_v': '0,290165', 'Initial_atomic_coordinate_w': '0,738577', "Calculated_atomic_coordinates_u'": '0,532457', "Calculated_atomic_coordinates_v'": '0,267534', "Calculated_atomic_coordinates_w'": '0,738691'}
# 72 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd768'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,59573', 'Initial_atomic_coordinate_v': '0,334659', 'Initial_atomic_coordinate_w': '0,82832', "Calculated_atomic_coordinates_u'": '0,601573', "Calculated_atomic_coordinates_v'": '0,314933', "Calculated_atomic_coordinates_w'": '0,827159'}
# 73 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd769'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,235864', 'Initial_atomic_coordinate_v': '0,366019', 'Initial_atomic_coordinate_w': '0,777038', "Calculated_atomic_coordinates_u'": '0,212606', "Calculated_atomic_coordinates_v'": '0,352715', "Calculated_atomic_coordinates_w'": '0,777407'}
# 74 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,244068', 'Initial_atomic_coordinate_v': '0,315433', 'Initial_atomic_coordinate_w': '0,866782', "Calculated_atomic_coordinates_u'": '0,224287', "Calculated_atomic_coordinates_v'": '0,299455', "Calculated_atomic_coordinates_w'": '0,866505'}
# 75 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,265092', 'Initial_atomic_coordinate_v': '0,487157', 'Initial_atomic_coordinate_w': '0,930884', "Calculated_atomic_coordinates_u'": '0,23954', "Calculated_atomic_coordinates_v'": '0,48116', "Calculated_atomic_coordinates_w'": '0,932119'}
# 76 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,648228', 'Initial_atomic_coordinate_v': '0,763458', 'Initial_atomic_coordinate_w': '0,969346', "Calculated_atomic_coordinates_u'": '0,654645', "Calculated_atomic_coordinates_v'": '0,778422', "Calculated_atomic_coordinates_w'": '0,969496'}
# 77 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,75699', 'Initial_atomic_coordinate_v': '0,575609', 'Initial_atomic_coordinate_w': '0,853961', "Calculated_atomic_coordinates_u'": '0,77189', "Calculated_atomic_coordinates_v'": '0,57763', "Calculated_atomic_coordinates_w'": '0,853688'}
# 78 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,408402', 'Initial_atomic_coordinate_v': '0,239639', 'Initial_atomic_coordinate_w': '0,892423', "Calculated_atomic_coordinates_u'": '0,400682', "Calculated_atomic_coordinates_v'": '0,217438', "Calculated_atomic_coordinates_w'": '0,892936'}
# 79 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd76f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,470355', 'Initial_atomic_coordinate_v': '0,257866', 'Initial_atomic_coordinate_w': '0,982166', "Calculated_atomic_coordinates_u'": '0,470821', "Calculated_atomic_coordinates_v'": '0,236035', "Calculated_atomic_coordinates_w'": '0,98165'}
# 80 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd770'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,637257', 'Initial_atomic_coordinate_v': '0,791312', 'Initial_atomic_coordinate_w': '0,032917', "Calculated_atomic_coordinates_u'": '0,636717', "Calculated_atomic_coordinates_v'": '0,803969', "Calculated_atomic_coordinates_w'": '0,032929'}
# 81 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd771'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,403783', 'Initial_atomic_coordinate_v': '0,690165', 'Initial_atomic_coordinate_w': '0,041689', "Calculated_atomic_coordinates_u'": '0,393472', "Calculated_atomic_coordinates_v'": '0,694676', "Calculated_atomic_coordinates_w'": '0,041784'}
# 82 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd772'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,31966', 'Initial_atomic_coordinate_v': '0,608137', 'Initial_atomic_coordinate_w': '0,111865', "Calculated_atomic_coordinates_u'": '0,30593', "Calculated_atomic_coordinates_v'": '0,607015', "Calculated_atomic_coordinates_w'": '0,112105'}
# 83 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd773'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,743096', 'Initial_atomic_coordinate_v': '0,760817', 'Initial_atomic_coordinate_w': '0,094321', "Calculated_atomic_coordinates_u'": '0,753137', "Calculated_atomic_coordinates_v'": '0,775437', "Calculated_atomic_coordinates_w'": '0,094168'}
# 84 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd774'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,677708', 'Initial_atomic_coordinate_v': '0,788935', 'Initial_atomic_coordinate_w': '0,164496', "Calculated_atomic_coordinates_u'": '0,682379', "Calculated_atomic_coordinates_v'": '0,804355', "Calculated_atomic_coordinates_w'": '0,164358'}
# 85 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd775'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,766249', 'Initial_atomic_coordinate_v': '0,735843', 'Initial_atomic_coordinate_w': '0,2259', "Calculated_atomic_coordinates_u'": '0,777945', "Calculated_atomic_coordinates_v'": '0,749432', "Calculated_atomic_coordinates_w'": '0,225798'}
# 86 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd776'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,713311', 'Initial_atomic_coordinate_v': '0,778677', 'Initial_atomic_coordinate_w': '0,296075', "Calculated_atomic_coordinates_u'": '0,720745', "Calculated_atomic_coordinates_v'": '0,794402', "Calculated_atomic_coordinates_w'": '0,296029'}
# 87 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd777'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,549619', 'Initial_atomic_coordinate_v': '0,276071', 'Initial_atomic_coordinate_w': '0,006602', "Calculated_atomic_coordinates_u'": '0,555071', "Calculated_atomic_coordinates_v'": '0,269279', "Calculated_atomic_coordinates_w'": '0,006501'}
# 88 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd778'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,233751', 'Initial_atomic_coordinate_v': '0,264157', 'Initial_atomic_coordinate_w': '0,059233', "Calculated_atomic_coordinates_u'": '0,219019', "Calculated_atomic_coordinates_v'": '0,246063', "Calculated_atomic_coordinates_w'": '0,059347'}
# 89 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd779'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,209389', 'Initial_atomic_coordinate_v': '0,3741', 'Initial_atomic_coordinate_w': '0,120637', "Calculated_atomic_coordinates_u'": '0,19467', "Calculated_atomic_coordinates_v'": '0,363701', "Calculated_atomic_coordinates_w'": '0,120952'}
# 90 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,21786', 'Initial_atomic_coordinate_v': '0,295564', 'Initial_atomic_coordinate_w': '0,190812', "Calculated_atomic_coordinates_u'": '0,205895', "Calculated_atomic_coordinates_v'": '0,280628', "Calculated_atomic_coordinates_w'": '0,191151'}
# 91 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,450381', 'Initial_atomic_coordinate_v': '0,723929', 'Initial_atomic_coordinate_w': '0,173268', "Calculated_atomic_coordinates_u'": '0,445071', "Calculated_atomic_coordinates_v'": '0,732091', "Calculated_atomic_coordinates_w'": '0,173231'}
# 92 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,359809', 'Initial_atomic_coordinate_v': '0,651213', 'Initial_atomic_coordinate_w': '0,243444', "Calculated_atomic_coordinates_u'": '0,348764', "Calculated_atomic_coordinates_v'": '0,654129', "Calculated_atomic_coordinates_w'": '0,243503'}
# 93 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,498332', 'Initial_atomic_coordinate_v': '0,751585', 'Initial_atomic_coordinate_w': '0,304847', "Calculated_atomic_coordinates_u'": '0,495486', "Calculated_atomic_coordinates_v'": '0,763508', "Calculated_atomic_coordinates_w'": '0,304887'}
# 94 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,403783', 'Initial_atomic_coordinate_v': '0,690165', 'Initial_atomic_coordinate_w': '0,375023', "Calculated_atomic_coordinates_u'": '0,39409', "Calculated_atomic_coordinates_v'": '0,694968', "Calculated_atomic_coordinates_w'": '0,375015'}
# 95 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd77f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,78214', 'Initial_atomic_coordinate_v': '0,704436', 'Initial_atomic_coordinate_w': '0,357479', "Calculated_atomic_coordinates_u'": '0,797217', "Calculated_atomic_coordinates_v'": '0,718068', "Calculated_atomic_coordinates_w'": '0,357196'}
# 96 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd780'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,743096', 'Initial_atomic_coordinate_v': '0,760817', 'Initial_atomic_coordinate_w': '0,427654', "Calculated_atomic_coordinates_u'": '0,754694', "Calculated_atomic_coordinates_v'": '0,777448', "Calculated_atomic_coordinates_w'": '0,427477'}
# 97 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd781'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,790335', 'Initial_atomic_coordinate_v': '0,667452', 'Initial_atomic_coordinate_w': '0,489058', "Calculated_atomic_coordinates_u'": '0,807952', "Calculated_atomic_coordinates_v'": '0,681054', "Calculated_atomic_coordinates_w'": '0,489132'}
# 98 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd782'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,766249', 'Initial_atomic_coordinate_v': '0,735843', 'Initial_atomic_coordinate_w': '0,559233', "Calculated_atomic_coordinates_u'": '0,780981', "Calculated_atomic_coordinates_v'": '0,753937', "Calculated_atomic_coordinates_w'": '0,559347'}
# 99 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd783'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,74492', 'Initial_atomic_coordinate_v': '0,485609', 'Initial_atomic_coordinate_w': '0,015373', "Calculated_atomic_coordinates_u'": '0,75736', "Calculated_atomic_coordinates_v'": '0,487774', "Calculated_atomic_coordinates_w'": '0,015348'}
# 100 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd784'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,782959', 'Initial_atomic_coordinate_v': '0,580915', 'Initial_atomic_coordinate_w': '0,085549', "Calculated_atomic_coordinates_u'": '0,795642', "Calculated_atomic_coordinates_v'": '0,588879', "Calculated_atomic_coordinates_w'": '0,085488'}
# 101 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd785'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,406938', 'Initial_atomic_coordinate_v': '0,214257', 'Initial_atomic_coordinate_w': '0,068005', "Calculated_atomic_coordinates_u'": '0,402862', "Calculated_atomic_coordinates_v'": '0,199315', "Calculated_atomic_coordinates_w'": '0,067847'}
# 102 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd786'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,501668', 'Initial_atomic_coordinate_v': '0,248415', 'Initial_atomic_coordinate_w': '0,138181', "Calculated_atomic_coordinates_u'": '0,505401', "Calculated_atomic_coordinates_v'": '0,236223', "Calculated_atomic_coordinates_w'": '0,137935'}
# 103 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd787'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,362743', 'Initial_atomic_coordinate_v': '0,208688', 'Initial_atomic_coordinate_w': '0,199584', "Calculated_atomic_coordinates_u'": '0,358686', "Calculated_atomic_coordinates_v'": '0,192911', "Calculated_atomic_coordinates_w'": '0,199771'}
# 104 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd788'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,453671', 'Initial_atomic_coordinate_v': '0,227621', 'Initial_atomic_coordinate_w': '0,269759', "Calculated_atomic_coordinates_u'": '0,458173', "Calculated_atomic_coordinates_v'": '0,215511', "Calculated_atomic_coordinates_w'": '0,269828'}
# 105 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd789'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,217041', 'Initial_atomic_coordinate_v': '0,419085', 'Initial_atomic_coordinate_w': '0,252216', "Calculated_atomic_coordinates_u'": '0,204773', "Calculated_atomic_coordinates_v'": '0,412301', "Calculated_atomic_coordinates_w'": '0,252384'}
# 106 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,209665', 'Initial_atomic_coordinate_v': '0,332548', 'Initial_atomic_coordinate_w': '0,322391', "Calculated_atomic_coordinates_u'": '0,198094', "Calculated_atomic_coordinates_v'": '0,319888', "Calculated_atomic_coordinates_w'": '0,322493'}
# 107 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,232411', 'Initial_atomic_coordinate_v': '0,466278', 'Initial_atomic_coordinate_w': '0,383795', "Calculated_atomic_coordinates_u'": '0,219043', "Calculated_atomic_coordinates_v'": '0,460817', "Calculated_atomic_coordinates_w'": '0,383849'}
# 108 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,209389', 'Initial_atomic_coordinate_v': '0,3741', 'Initial_atomic_coordinate_w': '0,45397', "Calculated_atomic_coordinates_u'": '0,196708', "Calculated_atomic_coordinates_v'": '0,362862', "Calculated_atomic_coordinates_w'": '0,454006'}
# 109 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,546329', 'Initial_atomic_coordinate_v': '0,772379', 'Initial_atomic_coordinate_w': '0,436426', "Calculated_atomic_coordinates_u'": '0,546758', "Calculated_atomic_coordinates_v'": '0,784127', "Calculated_atomic_coordinates_w'": '0,436204'}
# 110 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,450381', 'Initial_atomic_coordinate_v': '0,723929', 'Initial_atomic_coordinate_w': '0,506602', "Calculated_atomic_coordinates_u'": '0,444929', "Calculated_atomic_coordinates_v'": '0,730721', "Calculated_atomic_coordinates_w'": '0,506501'}
# 111 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd78f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,593062', 'Initial_atomic_coordinate_v': '0,785743', 'Initial_atomic_coordinate_w': '0,568005', "Calculated_atomic_coordinates_u'": '0,597138', "Calculated_atomic_coordinates_v'": '0,800685', "Calculated_atomic_coordinates_w'": '0,567847'}
# 112 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd790'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,498332', 'Initial_atomic_coordinate_v': '0,751585', 'Initial_atomic_coordinate_w': '0,638181', "Calculated_atomic_coordinates_u'": '0,494599', "Calculated_atomic_coordinates_v'": '0,763777', "Calculated_atomic_coordinates_w'": '0,637935'}
# 113 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd791'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,78214', 'Initial_atomic_coordinate_v': '0,704436', 'Initial_atomic_coordinate_w': '0,690812', "Calculated_atomic_coordinates_u'": '0,794105', "Calculated_atomic_coordinates_v'": '0,719372', "Calculated_atomic_coordinates_w'": '0,691151'}
# 114 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd792'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,790335', 'Initial_atomic_coordinate_v': '0,667452', 'Initial_atomic_coordinate_w': '0,822391', "Calculated_atomic_coordinates_u'": '0,801906', "Calculated_atomic_coordinates_v'": '0,680112', "Calculated_atomic_coordinates_w'": '0,822493'}
# 115 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd793'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,71557', 'Initial_atomic_coordinate_v': '0,437889', 'Initial_atomic_coordinate_w': '0,146952', "Calculated_atomic_coordinates_u'": '0,72519', "Calculated_atomic_coordinates_v'": '0,436767', "Calculated_atomic_coordinates_w'": '0,146746'}
# 116 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd794'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,767589', 'Initial_atomic_coordinate_v': '0,533722', 'Initial_atomic_coordinate_w': '0,217128', "Calculated_atomic_coordinates_u'": '0,781561', "Calculated_atomic_coordinates_v'": '0,539864', "Calculated_atomic_coordinates_w'": '0,216971'}
# 117 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd795'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,68034', 'Initial_atomic_coordinate_v': '0,391863', 'Initial_atomic_coordinate_w': '0,278531', "Calculated_atomic_coordinates_u'": '0,693294', "Calculated_atomic_coordinates_v'": '0,389132', "Calculated_atomic_coordinates_w'": '0,27849'}
# 118 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd796'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,74492', 'Initial_atomic_coordinate_v': '0,485609', 'Initial_atomic_coordinate_w': '0,348707', "Calculated_atomic_coordinates_u'": '0,763292', "Calculated_atomic_coordinates_v'": '0,491718', "Calculated_atomic_coordinates_w'": '0,348524'}
# 119 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd797'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,322292', 'Initial_atomic_coordinate_v': '0,211065', 'Initial_atomic_coordinate_w': '0,331163', "Calculated_atomic_coordinates_u'": '0,318833', "Calculated_atomic_coordinates_v'": '0,197217', "Calculated_atomic_coordinates_w'": '0,331324'}
# 120 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd798'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,406938', 'Initial_atomic_coordinate_v': '0,214257', 'Initial_atomic_coordinate_w': '0,401338', "Calculated_atomic_coordinates_u'": '0,411354', "Calculated_atomic_coordinates_v'": '0,203804', "Calculated_atomic_coordinates_w'": '0,401423'}
# 121 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd799'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,286689', 'Initial_atomic_coordinate_v': '0,221323', 'Initial_atomic_coordinate_w': '0,462742', "Calculated_atomic_coordinates_u'": '0,280845', "Calculated_atomic_coordinates_v'": '0,207219', "Calculated_atomic_coordinates_w'": '0,462711'}
# 122 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79a'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,362743', 'Initial_atomic_coordinate_v': '0,208688', 'Initial_atomic_coordinate_w': '0,532917', "Calculated_atomic_coordinates_u'": '0,363282', "Calculated_atomic_coordinates_v'": '0,196031', "Calculated_atomic_coordinates_w'": '0,532929'}
# 123 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79b'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,25508', 'Initial_atomic_coordinate_v': '0,514391', 'Initial_atomic_coordinate_w': '0,515373', "Calculated_atomic_coordinates_u'": '0,242639', "Calculated_atomic_coordinates_v'": '0,512226', "Calculated_atomic_coordinates_w'": '0,515348'}
# 124 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79c'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,217041', 'Initial_atomic_coordinate_v': '0,419085', 'Initial_atomic_coordinate_w': '0,585549', "Calculated_atomic_coordinates_u'": '0,204358', "Calculated_atomic_coordinates_v'": '0,411121', "Calculated_atomic_coordinates_w'": '0,585488'}
# 125 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79d'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,28443', 'Initial_atomic_coordinate_v': '0,562111', 'Initial_atomic_coordinate_w': '0,646952', "Calculated_atomic_coordinates_u'": '0,27481', "Calculated_atomic_coordinates_v'": '0,563233', "Calculated_atomic_coordinates_w'": '0,646746'}
# 126 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79e'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,232411', 'Initial_atomic_coordinate_v': '0,466278', 'Initial_atomic_coordinate_w': '0,717128', "Calculated_atomic_coordinates_u'": '0,218439', "Calculated_atomic_coordinates_v'": '0,460136', "Calculated_atomic_coordinates_w'": '0,716971'}
# 127 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd79f'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,637257', 'Initial_atomic_coordinate_v': '0,791312', 'Initial_atomic_coordinate_w': '0,699584', "Calculated_atomic_coordinates_u'": '0,641314', "Calculated_atomic_coordinates_v'": '0,807089', "Calculated_atomic_coordinates_w'": '0,699771'}
# 128 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd7a0'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,546329', 'Initial_atomic_coordinate_v': '0,772379', 'Initial_atomic_coordinate_w': '0,769759', "Calculated_atomic_coordinates_u'": '0,541827', "Calculated_atomic_coordinates_v'": '0,784489', "Calculated_atomic_coordinates_w'": '0,769828'}
# 129 : {'_id': ObjectId('6216b4a685eeb4bf2dbbd7a1'), 'Chiral_indice_n': 3, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,677708', 'Initial_atomic_coordinate_v': '0,788935', 'Initial_atomic_coordinate_w': '0,831163', "Calculated_atomic_coordinates_u'": '0,681167', "Calculated_atomic_coordinates_v'": '0,802783', "Calculated_atomic_coordinates_w'": '0,831324'}
# ...
# 6674 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf132'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,786233', 'Initial_atomic_coordinate_v': '0,39348', 'Initial_atomic_coordinate_w': '0,819714', "Calculated_atomic_coordinates_u'": '0,788721', "Calculated_atomic_coordinates_v'": '0,390635', "Calculated_atomic_coordinates_w'": '0,819784'}
# 6675 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf133'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,544941', 'Initial_atomic_coordinate_v': '0,172827', 'Initial_atomic_coordinate_w': '0,797061', "Calculated_atomic_coordinates_u'": '0,544733', "Calculated_atomic_coordinates_v'": '0,168082', "Calculated_atomic_coordinates_w'": '0,79707'}
# 6676 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf134'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,569471', 'Initial_atomic_coordinate_v': '0,188115', 'Initial_atomic_coordinate_w': '0,829423', "Calculated_atomic_coordinates_u'": '0,569077', "Calculated_atomic_coordinates_v'": '0,183594', "Calculated_atomic_coordinates_w'": '0,829442'}
# 6677 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf135'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,458375', 'Initial_atomic_coordinate_v': '0,129236', 'Initial_atomic_coordinate_w': '0,850459', "Calculated_atomic_coordinates_u'": '0,456037', "Calculated_atomic_coordinates_v'": '0,123364', "Calculated_atomic_coordinates_w'": '0,850403'}
# 6678 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf136'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,483087', 'Initial_atomic_coordinate_v': '0,140045', 'Initial_atomic_coordinate_w': '0,882821', "Calculated_atomic_coordinates_u'": '0,48124', "Calculated_atomic_coordinates_v'": '0,133088', "Calculated_atomic_coordinates_w'": '0,882741'}
# 6679 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf137'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,234387', 'Initial_atomic_coordinate_v': '0,101011', 'Initial_atomic_coordinate_w': '0,860167', "Calculated_atomic_coordinates_u'": '0,230481', "Calculated_atomic_coordinates_v'": '0,095891', "Calculated_atomic_coordinates_w'": '0,860089'}
# 6680 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf138'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,253619', 'Initial_atomic_coordinate_v': '0,097099', 'Initial_atomic_coordinate_w': '0,89253', "Calculated_atomic_coordinates_u'": '0,249808', "Calculated_atomic_coordinates_v'": '0,089807', "Calculated_atomic_coordinates_w'": '0,892488'}
# 6681 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf139'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,175292', 'Initial_atomic_coordinate_v': '0,126248', 'Initial_atomic_coordinate_w': '0,913565', "Calculated_atomic_coordinates_u'": '0,170801', "Calculated_atomic_coordinates_v'": '0,119383', "Calculated_atomic_coordinates_w'": '0,913652'}
# 6682 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13a'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,190777', 'Initial_atomic_coordinate_v': '0,11724', 'Initial_atomic_coordinate_w': '0,945928', "Calculated_atomic_coordinates_u'": '0,18782', "Calculated_atomic_coordinates_v'": '0,110934', "Calculated_atomic_coordinates_w'": '0,946052'}
# 6683 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13b'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,094016', 'Initial_atomic_coordinate_v': '0,284836', 'Initial_atomic_coordinate_w': '0,923274', "Calculated_atomic_coordinates_u'": '0,089097', "Calculated_atomic_coordinates_v'": '0,280828', "Calculated_atomic_coordinates_w'": '0,9234'}
# 6684 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13c'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,095628', 'Initial_atomic_coordinate_v': '0,26423', 'Initial_atomic_coordinate_w': '0,955637', "Calculated_atomic_coordinates_u'": '0,092112', "Calculated_atomic_coordinates_v'": '0,260802', "Calculated_atomic_coordinates_w'": '0,955703'}
# 6685 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13d'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,100256', 'Initial_atomic_coordinate_v': '0,362731', 'Initial_atomic_coordinate_w': '0,976672', "Calculated_atomic_coordinates_u'": '0,098278', "Calculated_atomic_coordinates_v'": '0,361947', "Calculated_atomic_coordinates_w'": '0,976649'}
# 6686 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13e'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,213767', 'Initial_atomic_coordinate_v': '0,60652', 'Initial_atomic_coordinate_w': '0,986381', "Calculated_atomic_coordinates_u'": '0,211359', "Calculated_atomic_coordinates_v'": '0,608524', "Calculated_atomic_coordinates_w'": '0,986375'}
# 6687 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf13f'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,894594', 'Initial_atomic_coordinate_v': '0,613706', 'Initial_atomic_coordinate_w': '0,777643', "Calculated_atomic_coordinates_u'": '0,897928', "Calculated_atomic_coordinates_v'": '0,614438', "Calculated_atomic_coordinates_w'": '0,777711'}
# 6688 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf140'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,899744', 'Initial_atomic_coordinate_v': '0,637269', 'Initial_atomic_coordinate_w': '0,810005', "Calculated_atomic_coordinates_u'": '0,90248', "Calculated_atomic_coordinates_v'": '0,637421', "Calculated_atomic_coordinates_w'": '0,809972'}
# 6689 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf141'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,865182', 'Initial_atomic_coordinate_v': '0,52849', 'Initial_atomic_coordinate_w': '0,831041', "Calculated_atomic_coordinates_u'": '0,867995', "Calculated_atomic_coordinates_v'": '0,527093', "Calculated_atomic_coordinates_w'": '0,831025'}
# 6690 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf142'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,875351', 'Initial_atomic_coordinate_v': '0,553141', 'Initial_atomic_coordinate_w': '0,863404', "Calculated_atomic_coordinates_u'": '0,877488', "Calculated_atomic_coordinates_v'": '0,551858', "Calculated_atomic_coordinates_w'": '0,863396'}
# 6691 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf143'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,697378', 'Initial_atomic_coordinate_v': '0,291204', 'Initial_atomic_coordinate_w': '0,84075', "Calculated_atomic_coordinates_u'": '0,698623', "Calculated_atomic_coordinates_v'": '0,286617', "Calculated_atomic_coordinates_w'": '0,840799'}
# 6692 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf144'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,718656', 'Initial_atomic_coordinate_v': '0,312836', 'Initial_atomic_coordinate_w': '0,873112', "Calculated_atomic_coordinates_u'": '0,719757', "Calculated_atomic_coordinates_v'": '0,308037', "Calculated_atomic_coordinates_w'": '0,873142'}
# 6693 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf145'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,617665', 'Initial_atomic_coordinate_v': '0,22211', 'Initial_atomic_coordinate_w': '0,894148', "Calculated_atomic_coordinates_u'": '0,617778', "Calculated_atomic_coordinates_v'": '0,215072', "Calculated_atomic_coordinates_w'": '0,894161'}
# 6694 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf146'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,641149', 'Initial_atomic_coordinate_v': '0,240691', 'Initial_atomic_coordinate_w': '0,92651', "Calculated_atomic_coordinates_u'": '0,643454', "Calculated_atomic_coordinates_v'": '0,235671', "Calculated_atomic_coordinates_w'": '0,926447'}
# 6695 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf147'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,373698', 'Initial_atomic_coordinate_v': '0,102482', 'Initial_atomic_coordinate_w': '0,903857', "Calculated_atomic_coordinates_u'": '0,370827', "Calculated_atomic_coordinates_v'": '0,093913', "Calculated_atomic_coordinates_w'": '0,903893'}
# 6696 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf148'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,397471', 'Initial_atomic_coordinate_v': '0,108322', 'Initial_atomic_coordinate_w': '0,936219', "Calculated_atomic_coordinates_u'": '0,396389', "Calculated_atomic_coordinates_v'": '0,100689', "Calculated_atomic_coordinates_w'": '0,936294'}
# 6697 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf149'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,294757', 'Initial_atomic_coordinate_v': '0,09378', 'Initial_atomic_coordinate_w': '0,957255', "Calculated_atomic_coordinates_u'": '0,292963', "Calculated_atomic_coordinates_v'": '0,08676', "Calculated_atomic_coordinates_w'": '0,957424'}
# 6698 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14a'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,316511', 'Initial_atomic_coordinate_v': '0,094385', 'Initial_atomic_coordinate_w': '0,989617', "Calculated_atomic_coordinates_u'": '0,316505', "Calculated_atomic_coordinates_v'": '0,089567', "Calculated_atomic_coordinates_w'": '0,989757'}
# 6699 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14b'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,130942', 'Initial_atomic_coordinate_v': '0,168457', 'Initial_atomic_coordinate_w': '0,966963', "Calculated_atomic_coordinates_u'": '0,128579', "Calculated_atomic_coordinates_v'": '0,164641', "Calculated_atomic_coordinates_w'": '0,967066'}
# 6700 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14c'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,141978', 'Initial_atomic_coordinate_v': '0,154764', 'Initial_atomic_coordinate_w': '0,999326', "Calculated_atomic_coordinates_u'": '0,140654', "Calculated_atomic_coordinates_v'": '0,151916', "Calculated_atomic_coordinates_w'": '0,999354'}
# 6701 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14d'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,90557', 'Initial_atomic_coordinate_v': '0,682779', 'Initial_atomic_coordinate_w': '0,87473', "Calculated_atomic_coordinates_u'": '0,910659', "Calculated_atomic_coordinates_v'": '0,683466', "Calculated_atomic_coordinates_w'": '0,874672'}
# 6702 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14e'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,819187', 'Initial_atomic_coordinate_v': '0,44198', 'Initial_atomic_coordinate_w': '0,884439', "Calculated_atomic_coordinates_u'": '0,820184', "Calculated_atomic_coordinates_v'": '0,43914', "Calculated_atomic_coordinates_w'": '0,884456'}
# 6703 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf14f'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,833912', 'Initial_atomic_coordinate_v': '0,466599', 'Initial_atomic_coordinate_w': '0,916802', "Calculated_atomic_coordinates_u'": '0,837198', "Calculated_atomic_coordinates_v'": '0,465474', "Calculated_atomic_coordinates_w'": '0,916721'}
# 6704 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf150'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,758696', 'Initial_atomic_coordinate_v': '0,358105', 'Initial_atomic_coordinate_w': '0,937837', "Calculated_atomic_coordinates_u'": '0,763288', "Calculated_atomic_coordinates_v'": '0,355456', "Calculated_atomic_coordinates_w'": '0,937767'}
# 6705 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf151'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,777309', 'Initial_atomic_coordinate_v': '0,381574', 'Initial_atomic_coordinate_w': '0,9702', "Calculated_atomic_coordinates_u'": '0,783865', "Calculated_atomic_coordinates_v'": '0,381067', "Calculated_atomic_coordinates_w'": '0,970095'}
# 6706 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf152'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,532608', 'Initial_atomic_coordinate_v': '0,165636', 'Initial_atomic_coordinate_w': '0,947546', "Calculated_atomic_coordinates_u'": '0,533671', "Calculated_atomic_coordinates_v'": '0,161648', "Calculated_atomic_coordinates_w'": '0,947582'}
# 6707 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf153'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,557233', 'Initial_atomic_coordinate_v': '0,180322', 'Initial_atomic_coordinate_w': '0,979908', "Calculated_atomic_coordinates_u'": '0,560166', "Calculated_atomic_coordinates_v'": '0,178879', "Calculated_atomic_coordinates_w'": '0,979964'}
# 6708 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf154'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,891467', 'Initial_atomic_coordinate_v': '0,601759', 'Initial_atomic_coordinate_w': '0,928128', "Calculated_atomic_coordinates_u'": '0,898996', "Calculated_atomic_coordinates_v'": '0,60292', "Calculated_atomic_coordinates_w'": '0,928073'}
# 6709 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf155'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,897354', 'Initial_atomic_coordinate_v': '0,625546', 'Initial_atomic_coordinate_w': '0,960491', "Calculated_atomic_coordinates_u'": '0,905724', "Calculated_atomic_coordinates_v'": '0,628332', "Calculated_atomic_coordinates_w'": '0,960361'}
# 6710 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf156'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,859586', 'Initial_atomic_coordinate_v': '0,516119', 'Initial_atomic_coordinate_w': '0,981527', "Calculated_atomic_coordinates_u'": '0,866117', "Calculated_atomic_coordinates_v'": '0,517672', "Calculated_atomic_coordinates_w'": '0,981461'}
# 6711 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf157'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 2, 'Initial_atomic_coordinate_u': '0,686458', 'Initial_atomic_coordinate_v': '0,280674', 'Initial_atomic_coordinate_w': '0,991235', "Calculated_atomic_coordinates_u'": '0,691286', "Calculated_atomic_coordinates_v'": '0,279397', "Calculated_atomic_coordinates_w'": '0,991203'}
# 6712 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf158'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 3, 'Initial_atomic_coordinate_u': '0,90725', 'Initial_atomic_coordinate_v': '0,767129', 'Initial_atomic_coordinate_w': '0,008301', "Calculated_atomic_coordinates_u'": '0,913575', "Calculated_atomic_coordinates_v'": '0,772588', "Calculated_atomic_coordinates_w'": '0,008471'}
# 6713 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf159'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 3, 'Initial_atomic_coordinate_u': '0,913739', 'Initial_atomic_coordinate_v': '0,712975', 'Initial_atomic_coordinate_w': '0,162147', "Calculated_atomic_coordinates_u'": '0,919677', "Calculated_atomic_coordinates_v'": '0,717628', "Calculated_atomic_coordinates_w'": '0,161936'}
# 6714 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf15a'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 3, 'Initial_atomic_coordinate_u': '0,670997', 'Initial_atomic_coordinate_v': '0,91183', 'Initial_atomic_coordinate_w': '0,085224', "Calculated_atomic_coordinates_u'": '0,676848', "Calculated_atomic_coordinates_v'": '0,923074', "Calculated_atomic_coordinates_w'": '0,08499'}
# 6715 : {'_id': ObjectId('6216b4a685eeb4bf2dbbf15b'), 'Chiral_indice_n': 9, 'Chiral_indice_m': 3, 'Initial_atomic_coordinate_u': '0,863071', 'Initial_atomic_coordinate_v': '0,853456', 'Initial_atomic_coordinate_w': '0,033942', "Calculated_atomic_coordinates_u'": '0,86941', "Calculated_atomic_coordinates_v'": '0,860032', "Calculated_atomic_coordinates_w'": '0,034375'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
mdb.filter_all_Data("carbon_collection",Chiral_indice_n = ['$in',[2]],Chiral_indice_m=['$in',[1,2]])
# Out:
# Found 28 records
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd720'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,679005', 'Initial_atomic_coordinate_v': '0,701318', 'Initial_atomic_coordinate_w': '0,017033', "Calculated_atomic_coordinates_u'": '0,721039', "Calculated_atomic_coordinates_v'": '0,730232', "Calculated_atomic_coordinates_w'": '0,017014'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd721'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,717298', 'Initial_atomic_coordinate_v': '0,642129', 'Initial_atomic_coordinate_w': '0,231319', "Calculated_atomic_coordinates_u'": '0,738414', "Calculated_atomic_coordinates_v'": '0,65675', "Calculated_atomic_coordinates_w'": '0,232369'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd722'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,489336', 'Initial_atomic_coordinate_v': '0,303751', 'Initial_atomic_coordinate_w': '0,088462', "Calculated_atomic_coordinates_u'": '0,477676', "Calculated_atomic_coordinates_v'": '0,263221', "Calculated_atomic_coordinates_w'": '0,088712'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd723'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,413957', 'Initial_atomic_coordinate_v': '0,632996', 'Initial_atomic_coordinate_w': '0,040843', "Calculated_atomic_coordinates_u'": '0,408823', "Calculated_atomic_coordinates_v'": '0,657897', "Calculated_atomic_coordinates_w'": '0,039796'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd724'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,334292', 'Initial_atomic_coordinate_v': '0,543401', 'Initial_atomic_coordinate_w': '0,15989', "Calculated_atomic_coordinates_u'": '0,303349', "Calculated_atomic_coordinates_v'": '0,558807', "Calculated_atomic_coordinates_w'": '0,157373'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd725'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,510664', 'Initial_atomic_coordinate_v': '0,696249', 'Initial_atomic_coordinate_w': '0,255128', "Calculated_atomic_coordinates_u'": '0,496977', "Calculated_atomic_coordinates_v'": '0,725608', "Calculated_atomic_coordinates_w'": '0,25597'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd726'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,413957', 'Initial_atomic_coordinate_v': '0,632996', 'Initial_atomic_coordinate_w': '0,374176', "Calculated_atomic_coordinates_u'": '0,390878', "Calculated_atomic_coordinates_v'": '0,657645', "Calculated_atomic_coordinates_w'": '0,374735'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd727'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,712552', 'Initial_atomic_coordinate_v': '0,55479', 'Initial_atomic_coordinate_w': '0,112271', "Calculated_atomic_coordinates_u'": '0,750056', "Calculated_atomic_coordinates_v'": '0,561494', "Calculated_atomic_coordinates_w'": '0,114944'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd728'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,320995', 'Initial_atomic_coordinate_v': '0,298682', 'Initial_atomic_coordinate_w': '0,1837', "Calculated_atomic_coordinates_u'": '0,281301', "Calculated_atomic_coordinates_v'": '0,261433', "Calculated_atomic_coordinates_w'": '0,182779'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd729'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,394742', 'Initial_atomic_coordinate_v': '0,279367', 'Initial_atomic_coordinate_w': '0,302747', "Calculated_atomic_coordinates_u'": '0,35086', "Calculated_atomic_coordinates_v'": '0,2335', "Calculated_atomic_coordinates_w'": '0,302196'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72a'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,282702', 'Initial_atomic_coordinate_v': '0,357871', 'Initial_atomic_coordinate_w': '0,397985', "Calculated_atomic_coordinates_u'": '0,229138', "Calculated_atomic_coordinates_v'": '0,328729', "Calculated_atomic_coordinates_w'": '0,398581'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72b'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,320995', 'Initial_atomic_coordinate_v': '0,298682', 'Initial_atomic_coordinate_w': '0,517033', "Calculated_atomic_coordinates_u'": '0,278752', "Calculated_atomic_coordinates_v'": '0,269615', "Calculated_atomic_coordinates_w'": '0,51733'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72c'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,605258', 'Initial_atomic_coordinate_v': '0,720633', 'Initial_atomic_coordinate_w': '0,469414', "Calculated_atomic_coordinates_u'": '0,613415', "Calculated_atomic_coordinates_v'": '0,760009', "Calculated_atomic_coordinates_w'": '0,469452'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72d'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,510664', 'Initial_atomic_coordinate_v': '0,696249', 'Initial_atomic_coordinate_w': '0,588462', "Calculated_atomic_coordinates_u'": '0,521991', "Calculated_atomic_coordinates_v'": '0,736991', "Calculated_atomic_coordinates_w'": '0,588946'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72e'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,679005', 'Initial_atomic_coordinate_v': '0,701318', 'Initial_atomic_coordinate_w': '0,6837', "Calculated_atomic_coordinates_u'": '0,718811', "Calculated_atomic_coordinates_v'": '0,738577', "Calculated_atomic_coordinates_w'": '0,68244'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd72f'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,605258', 'Initial_atomic_coordinate_v': '0,720633', 'Initial_atomic_coordinate_w': '0,802747', "Calculated_atomic_coordinates_u'": '0,649178', "Calculated_atomic_coordinates_v'": '0,766301', "Calculated_atomic_coordinates_w'": '0,80193'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd730'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,665708', 'Initial_atomic_coordinate_v': '0,456599', 'Initial_atomic_coordinate_w': '0,326557', "Calculated_atomic_coordinates_u'": '0,680389', "Calculated_atomic_coordinates_v'": '0,444562', "Calculated_atomic_coordinates_w'": '0,327502'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd731'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,712552', 'Initial_atomic_coordinate_v': '0,55479', 'Initial_atomic_coordinate_w': '0,445605', "Calculated_atomic_coordinates_u'": '0,737216', "Calculated_atomic_coordinates_v'": '0,552056', "Calculated_atomic_coordinates_w'": '0,443517'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd732'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,586043', 'Initial_atomic_coordinate_v': '0,367004', 'Initial_atomic_coordinate_w': '0,540843', "Calculated_atomic_coordinates_u'": '0,591153', "Calculated_atomic_coordinates_v'": '0,342069', "Calculated_atomic_coordinates_w'": '0,540172'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd733'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,665708', 'Initial_atomic_coordinate_v': '0,456599', 'Initial_atomic_coordinate_w': '0,65989', "Calculated_atomic_coordinates_u'": '0,697242', "Calculated_atomic_coordinates_v'": '0,441516', "Calculated_atomic_coordinates_w'": '0,657521'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd734'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,287448', 'Initial_atomic_coordinate_v': '0,44521', 'Initial_atomic_coordinate_w': '0,612271', "Calculated_atomic_coordinates_u'": '0,249571', "Calculated_atomic_coordinates_v'": '0,438057', "Calculated_atomic_coordinates_w'": '0,614939'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd735'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,282702', 'Initial_atomic_coordinate_v': '0,357871', 'Initial_atomic_coordinate_w': '0,731319', "Calculated_atomic_coordinates_u'": '0,262916', "Calculated_atomic_coordinates_v'": '0,343512', "Calculated_atomic_coordinates_w'": '0,732213'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd736'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,334292', 'Initial_atomic_coordinate_v': '0,543401', 'Initial_atomic_coordinate_w': '0,826557', "Calculated_atomic_coordinates_u'": '0,320053', "Calculated_atomic_coordinates_v'": '0,555754', "Calculated_atomic_coordinates_w'": '0,827503'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd737'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,287448', 'Initial_atomic_coordinate_v': '0,44521', 'Initial_atomic_coordinate_w': '0,945605', "Calculated_atomic_coordinates_u'": '0,262054', "Calculated_atomic_coordinates_v'": '0,44817', "Calculated_atomic_coordinates_w'": '0,943402'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd738'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,717298', 'Initial_atomic_coordinate_v': '0,642129', 'Initial_atomic_coordinate_w': '0,897985', "Calculated_atomic_coordinates_u'": '0,770521', "Calculated_atomic_coordinates_v'": '0,670869', "Calculated_atomic_coordinates_w'": '0,898389'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd739'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,489336', 'Initial_atomic_coordinate_v': '0,303751', 'Initial_atomic_coordinate_w': '0,755128', "Calculated_atomic_coordinates_u'": '0,50356', "Calculated_atomic_coordinates_v'": '0,27443', "Calculated_atomic_coordinates_w'": '0,75629'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd73a'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,586043', 'Initial_atomic_coordinate_v': '0,367004', 'Initial_atomic_coordinate_w': '0,874176', "Calculated_atomic_coordinates_u'": '0,609', "Calculated_atomic_coordinates_v'": '0,342123', "Calculated_atomic_coordinates_w'": '0,875088'}
# {'_id': ObjectId('6216b4a685eeb4bf2dbbd73b'), 'Chiral_indice_n': 2, 'Chiral_indice_m': 1, 'Initial_atomic_coordinate_u': '0,394742', 'Initial_atomic_coordinate_v': '0,279367', 'Initial_atomic_coordinate_w': '0,969414', "Calculated_atomic_coordinates_u'": '0,385666', "Calculated_atomic_coordinates_v'": '0,240071', "Calculated_atomic_coordinates_w'": '0,969157'}

# %%
mdb.update_Data("carbon_collection",{"Chiral_indice_n" : ['$in',[2]],"Chiral_indice_m":['$in',[1,2]]},{"Chiral_indice_n":33})
# Out:
# Updated 28 records

# %%
mdb.filter_all_Data("carbon_collection",Chiral_indice_n = ['$in',[2]],Chiral_indice_m=['$in',[1,2]])
#No records found since records were updated
# Out:
# Found 0 records

# %%
mdb.drop_collection("carbon_collection")
# Out:
# carbon_collection dropped
